# %%
import pandas as pd

# %%
df = pd.read_csv('crateri_marte.csv')

# %%
def filter_diam(db,diam_min):
    return db[(db['diam'] >= diam_min)]

# %%
df1= filter_diam(df, 8)
df1.to_csv('crateri_marte_filtered.csv',index=False)
